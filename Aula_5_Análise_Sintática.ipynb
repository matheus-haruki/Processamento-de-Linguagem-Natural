# %% [markdown]
# <a href="https://colab.research.google.com/github/matheus-haruki/Processamento-de-Linguagem-Natural/blob/main/Aula_5_An%C3%A1lise_Sint%C3%A1tica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Início do processamento do Corpus

# %%
#Criar uma função para fazer a arbetura e leitura do arquivo

def ler(nome_arquivo):
  arquivo = open("/content/drive/MyDrive/Colab Notebooks/P1-PLN/Cópia de 2025.05 Ubirajara.txt", "r", encoding='utf-8')
  conteudo_arq = arquivo.read()
  arquivo.close()
  return conteudo_arq

# %%
texto = ler("/content/drive/MyDrive/Colab Notebooks/P1-PLN/Cópia de 2025.05 Ubirajara.txt")
print(len(texto))
print(texto)
# Out:
# 219835
# ﻿The Project Gutenberg eBook of Ubirajara: Lenda Tupi
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: Ubirajara: Lenda Tupi
#
# Author: José Martiniano de Alencar
#
# Release date: January 5, 2012 [eBook #38496]
#                 Most recently updated: January 8, 2021
#
# Language: Portuguese
#
# Credits: Produced by Júlio Reis, Fernanda Brojo, Manuela Alves,
#         Rory OConor and the Online Distributed Proofreading Team
#         at https://www.pgdp.net
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK UBIRAJARA: LENDA TUPI ***
#
#
#
#
# ...

# %% [markdown]
# Buscador de palavras

# %%
def buscador(alvo, texto):
  texto = texto.replace('\n',' ')
  texto = texto.replace('\t',' ')

  ocorrencias=[]

  encontrado_aqui = texto.find(alvo, 0)

  while encontrado_aqui > 0:
    pos_inicial = encontrado_aqui - (40 - len(alvo))
    trecho = texto[pos_inicial: pos_inicial + 80]

    ocorrencias.append (trecho)

    encontrado_aqui = texto. find(alvo, encontrado_aqui + 1)

  return ocorrencias

# %%
resultados = buscador(' peito ', texto)

for trecho in resultados:
  print(trecho)
# Out:
#  o chefe tocantim quem recebeu no peito a ponta farpada.  Quando o corpo robusto
# nça, escrava de Jaguarê, cravou o peito do inimigo.  «Elle caiu, o guerreiro che
#  labio de Jandira emudeceu; mas o peito soluçou.  A virjem conheceu que o amor d
# dos que os botões do cardo por um peito feroz, e as mãos lijeiras que tecem os f
# nte do Xingú.  As arvores que seu peito encontrava caíam lascadas.  Jurandir est
# . Os noivos cuidavam que era a do peito do tucano; mas ella sabia que era do pei
# tucano; mas ella sabia que era do peito da arára e que tinha as côres de seu gue
# s o grito de espanto sossobrou no peito dos guerreiros, e rompeu em um grito de
#  do guerreiro quando se cruzam ao peito para exprimir a amizade.  Ubirajara apan
# u guerreiro.  Ubirajara cinjiu ao peito com um e outro braço, a espoza e a virje

# %% [markdown]
# Segunda Etapa - Limpeza dos corpus

# %%
palavras = texto.split()

# %%
def limpar(lista):
  lixo = '.,:;?!"~•^~()[]€}/\|@#$%¨&*_+-='
  quase_limpo = [x.strip(lixo).lower() for x in lista]
  return [x for x in quase_limpo if x.isalpha() or '-' not in x]

# %%
teste = "Corre-se atrás do carro, corre se o carro for embora."
word = teste.split()
print(word)
# Out:
# ['Corre-se', 'atrás', 'do', 'carro,', 'corre', 'se', 'o', 'carro', 'for', 'embora.']

# %%
print(limpar(word))
# Out:
# ['atrás', 'do', 'carro', 'corre', 'se', 'o', 'carro', 'for', 'embora']

# %%
print(len(palavras))
palavras = limpar(palavras)
print(len(palavras))
# Out:
# 37139
# 36585

# %% [markdown]
# Exemplo - POS Tagging com Spacy

# %%
# !pip install spacy
# !python -m spacy download pt_core_news_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 83.0 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

nlp = spacy. load("pt_core_news_sm")

frase = input("Insira uma frase, gramaticalmente correta: ")

doc = nlp (frase)
for token in doc:
  print(f"{token. text} -> {token.pos_}")
# Out:
# Insira uma frase, gramaticalmente correta: Boa tarde pessoal, estou testenado e quase finalizando a atividade.
# Boa -> ADJ
# tarde -> ADV
# pessoal -> ADJ
# , -> PUNCT
# estou -> AUX
# testenado -> ADJ
# e -> CCONJ
# quase -> ADV
# finalizando -> VERB
# a -> DET
# atividade -> NOUN
# . -> PUNCT

# %% [markdown]
# Exemplo 2 - Pos Tagging com NLTK (somente em inglês)

# %%
# !pip install nltk

# %%
import nltk
nltk.download("punkt")
nltk.download("averaged_perceptron_tagger_eng")

frase = input("Insira uma frase coerente: ")
tokens = nltk.word_tokenize(frase)

pos_tags = nltk.pos_tag(tokens, tagset=None, lang='eng')

for palavra, classe in pos_tags:
    print(f'{palavra} -> {classe}')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# Insira uma frase coerente: In the first weekend since President Trump unveiled broad tariffs, many shoppers sought to get ahead of expected price hikes, while others showed patience.
# In -> IN
# the -> DT
# first -> JJ
# weekend -> NN
# since -> IN
# President -> NNP
# Trump -> NNP
# unveiled -> VBD
# broad -> JJ
# tariffs -> NNS
# , -> ,
# many -> JJ
# shoppers -> NNS
# sought -> VBD
# to -> TO
# get -> VB
# ahead -> RB
# of -> IN
# expected -> VBN
# price -> NN
# hikes -> NNS
# , -> ,
# while -> IN
# others -> NNS
# showed -> VBD
# patience -> NN
# . -> .

# %% [markdown]
# Exemplo 3 - Parsing de dependência com spacy

# %%
import spacy


nlp = spacy.load('pt_core_news_sm')

frase = "O gato preto dorme na cadeira."

doc = nlp(frase)

for token in doc:
    print(f"{token.text} -> {token.dep_} -> {token.head.text}")
# Out:
# O -> det -> gato
# gato -> ROOT -> gato
# preto -> amod -> gato
# dorme -> amod -> gato
# na -> case -> cadeira
# cadeira -> obl -> dorme
# . -> punct -> gato

# %% [markdown]
# Exemplo 4 - Análise de Dependência com spacy

# %%
import spacy
from spacy import displacy

nlp = spacy.load('pt_core_news_sm')

frase = "O gato preto dorme na cadeira."

doc = nlp(frase)

displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="d6ad4b1659144f2e84fdf784f0ae9d7a-0" class="displacy" width="1100" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">O</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">gato</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %% [markdown]
# Exemplo 5 - Análise de Constituência com NLTK

# %%
import nltk
from nltk import Tree

sintaxe = Tree('S', [
    Tree("NP", [Tree('DET', ['O']), Tree('N', ['gato'])]),
    Tree("VP", [
        Tree('V', ['dorme']),
        Tree('PP', [
            Tree('P', ['na']),
            Tree('NP', [Tree('N', ['cadeira'])])
        ])
    ])
])

sintaxe.pretty_print()
# Out:
#                S
#       _________|____
#      |              VP
#      |          ____|___
#      |         |        PP
#      |         |     ___|_____
#      NP        |    |         NP
#   ___|___      |    |         |
# DET      N     V    P         N
#  |       |     |    |         |
#  O      gato dorme  na     cadeira
